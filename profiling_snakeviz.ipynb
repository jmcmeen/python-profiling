# %% [markdown]
# # Visualise Profiling with snakeviz
#
# This notebook profiles `run_all_systems()` and opens an interactive icicle chart showing the call hierarchy and time spent in each function.

# %%
# %load_ext snakeviz

# %%
# %%snakeviz
# from run_all_systems import run_all_systems
# run_all_systems()
